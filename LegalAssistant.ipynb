# %%
# %pip install -U \
  langchain \
  langchain-community \
  langchain-google-genai \
  faiss-cpu \
  pandas \
  dotenv
# Out:
# Requirement already satisfied: langchain in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-community in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-google-genai in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (3.1.0)
# Requirement already satisfied: faiss-cpu in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (1.13.0)
# Requirement already satisfied: pandas in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: dotenv in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (0.9.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (0.4.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-google-genai) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (6.33.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["GOOGLE_API_KEY"] =""

# %%
import os
import json
import pandas as pd
from dotenv import load_dotenv

from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    GoogleGenerativeAIEmbeddings,
)
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()


DATA_PATH = "data/legal_cases.csv"
INDEX_DIR = "data/legal_faiss_index"

# LLM + Embeddings (Gemini)
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.2,
    convert_system_message_to_human=True,
)

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
def load_legal_cases(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)

    required_cols = [
        "case_id",
        "case_name",
        "Facts",
        "Issues",
        "Analysis of the Law",
        "Petitioner's Arguments",
        "Respondent's Arguments",
        "Court's Reasoning",
        "Conclusion",
    ]
    for c in required_cols:
        if c not in df.columns:
            raise ValueError(f"Missing column: {c}")

    # avoid NaN
    for c in required_cols:
        df[c] = df[c].fillna("")

    def build_full_text(row):
        parts = [
            f"Case Name: {row['case_name']}",
            "",
            "Facts:",
            row["Facts"],
            "",
            "Issues:",
            row["Issues"],
            "",
            "Analysis of the Law:",
            row["Analysis of the Law"],
            "",
            "Petitioner's Arguments:",
            row["Petitioner's Arguments"],
            "",
            "Respondent's Arguments:",
            row["Respondent's Arguments"],
            "",
            "Court's Reasoning:",
            row["Court's Reasoning"],
            "",
            "Conclusion:",
            row["Conclusion"],
        ]
        return "\n".join(parts)

    df["full_text"] = df.apply(build_full_text, axis=1)

    # you don’t have these, but we add simple defaults
    df["court"] = "Unknown Court"
    df["date"] = "Unknown Date"
    df["url"] = "N/A"
    df["case_id"] = df["case_id"].astype(str)

    return df[["case_id", "case_name", "court", "date", "url", "full_text"]]

df_cases = load_legal_cases(DATA_PATH)
df_cases.head()
# Out:
#   case_id                                          case_name          court  \
# 0                                                             Unknown Court
# 1                                                             Unknown Court
# 2     1.0  Imax Corporation vs E-City Entertainment (I) P...  Unknown Court
# 3                                                             Unknown Court
# 4                                                             Unknown Court
#
#            date  url                                          full_text
# 0  Unknown Date  N/A  Case Name: \n\nFacts:\n\n\nIssues:\n\n\nAnalys...
# 1  Unknown Date  N/A  Case Name: \n\nFacts:\n\n\nIssues:\n\n\nAnalys...
# 2  Unknown Date  N/A  Case Name: Imax Corporation vs E-City Entertai...
# 3  Unknown Date  N/A  Case Name: \n\nFacts:\n4. I have collated the ...
# 4  Unknown Date  N/A  Case Name: \n\nFacts:\nIMAX Limited was incorp...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=600,
    chunk_overlap=100,
    separators=["\n\n", "\n", ". ", " ", ""],
)

def build_documents_from_df(df: pd.DataFrame):
    docs = []
    for _, row in df.iterrows():
        base_meta = {
            "case_id": row["case_id"],
            "case_name": row["case_name"],
            "court": row["court"],
            "date": row["date"],
            "url": row["url"],
        }
        chunks = text_splitter.split_text(row["full_text"])
        for i, chunk in enumerate(chunks):
            meta = base_meta.copy()
            meta["chunk_index"] = i
            docs.append(Document(page_content=chunk, metadata=meta))
    return docs

docs = build_documents_from_df(df_cases)
print(f"Total chunks: {len(docs)}")
print(docs[0])
# Out:
# Total chunks: 3640
# page_content='Case Name:
#
# Facts:
#
#
# Issues:
#
#
# Analysis of the Law:
#
#
# Petitioner's Arguments:
#
#
# Respondent's Arguments:
#
#
# Court's Reasoning:
#
#
# Conclusion:' metadata={'case_id': '', 'case_name': '', 'court': 'Unknown Court', 'date': 'Unknown Date', 'url': 'N/A', 'chunk_index': 0}

# %%
# from langchain_community.vectorstores import FAISS

# def build_or_load_vectorstore():
#     if os.path.exists(INDEX_DIR):
#         print(f"Loading existing index from {INDEX_DIR}")
#         vs = FAISS.load_local(
#             INDEX_DIR,
#             embeddings,
#             allow_dangerous_deserialization=True,
#         )
#         return vs

#     print("Building new vectorstore...")
#     docs = build_documents_from_df(df_cases)
#     vs = FAISS.from_documents(docs, embeddings)
#     os.makedirs(INDEX_DIR, exist_ok=True)
#     vs.save_local(INDEX_DIR)
#     print(f"Saved index to {INDEX_DIR}")
#     return vs

# vectorstore = build_or_load_vectorstore()
# retriever = vectorstore.as_retriever(search_kwargs={"k": 3})  # top 3 chunks

# %%
# %pip install -U langchain-core
# Out:
# Requirement already satisfied: langchain-core in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (1.0.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (0.4.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sujal\onedrive\desktop\mylegal\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.embeddings import DeterministicFakeEmbedding

embeddings = DeterministicFakeEmbedding(size=1536)

# %%
from langchain_community.vectorstores import FAISS
def build_or_load_vectorstore():
  if os.path.exists(INDEX_DIR):
        print(f"Loading existing index from {INDEX_DIR}")
        vs = FAISS.load_local(
            INDEX_DIR,
            embeddings,
            allow_dangerous_deserialization=True,
        )
        return vs
  docs = build_documents_from_df(df_cases)
  vs = FAISS.from_documents(docs, embeddings)
  os.makedirs(INDEX_DIR, exist_ok=True)
  vs.save_local(INDEX_DIR)
  print(f"Saved index to {INDEX_DIR}")
  return vs

vectorstore = build_or_load_vectorstore()
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})  # top 3 chunks
# Out:
# Saved index to data/legal_faiss_index

# %%
query = "tenant eviction without proper notice"
results = retriever.invoke(query)
for i, d in enumerate(results, start=1):
    print(f"\n=== RESULT {i} ===")
    print("Case:", d.metadata["case_name"])
    print("Excerpt:", d.page_content[:300], "...")
# Out:
# === RESULT 1 ===
# Case:
# Excerpt: Case Name:
#
# Facts:
#
#
# Issues:
#
#
# Analysis of the Law:
# 33. Mr. Khambata has submitted that in any case, the Rules are a piece of subordinate legislation. They cannot be considered to control the provisions of the Act especially if they cause conflict or absurdity in reading of the substantive provisio ...
#
# === RESULT 2 ===
# Case:
# Excerpt: Court's Reasoning:
# It further took a specific stand that even if the letter dated 28/11/2000 gave rise to legally binding obligations, the agreement was vitiated by misrepresentation and performance of such agreement has been terminated by abandonment or acquiescence by both the parties.
#
# Conclusion ...
#
# === RESULT 3 ===
# Case:
# Excerpt: . It being a well settled principle, right from the decision of the Apex Court in Renusagar (supra) that violation of Foreign Exchange Act and disregarding the orders of superior courts in India, would be regarded as being contrary to the fundamental policy of Indian Law, since the mandatory conditi ...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

def format_context(docs):
    lines = []
    for i, d in enumerate(docs, start=1):
        m = d.metadata
        lines.append(
            f"[CASE {i}] {m.get('case_name', 'Unknown')} "
            f"({m.get('court', 'Unknown Court')}, {m.get('date', 'Unknown Date')})\n"
            f"Excerpt:\n{d.page_content}\n"
            "-----"
        )
    return "\n".join(lines)

rag_prompt = PromptTemplate(
    input_variables=["question", "context"],
    template=(
        "You are a legal assistant for Indian case law. You will answer based ONLY "
        "on the provided case excerpts.\n\n"
        "If you are not sure, say you are not sure and suggest consulting a lawyer.\n\n"
        "Context (case excerpts):\n"
        "{context}\n\n"
        "User question:\n"
        "{question}\n\n"
        "Instructions:\n"
        "- Use only the information in the context.\n"
        "- Mention the relevant case names when explaining.\n"
        "- If you add your own general interpretation, mark it clearly.\n"
        "- End with: 'This is not formal legal advice.'\n\n"
        "Answer:\n"
    ),
)

rag_chain = (
    rag_prompt
    | llm
    | StrOutputParser()
)

# %%
def ask_legal_assistant(question: str) -> str:
    docs = retriever.invoke(question)

    if not docs:
        return (
            "I could not find any relevant cases in the current dataset for this question. "
            "Please consult a lawyer or a larger legal database. "
            "This is not formal legal advice."
        )

    context = format_context(docs)

    answer = rag_chain.invoke({"question": question, "context": context})
    return answer

# %%
questions = [
    "Can a company that owns sound recordings issue public performance licences without being registered as a copyright society under Section 33 of the Copyright Act?",
    "If a tenant is living for more than 10 years and the landlord tries to evict them without notice, what are the tenant’s rights under Indian law?",
]

for q in questions:
    print("QUESTION:", q)
    print()
    print(ask_legal_assistant(q))
    print("\n\n")
# Out:
# QUESTION: Can a company that owns sound recordings issue public performance licences without being registered as a copyright society under Section 33 of the Copyright Act?
#
# Based on the provided case excerpts, there is no information regarding Section 33 of the Copyright Act, copyright societies, or the ability of a company that owns sound recordings to issue public performance licenses.
#
# Therefore, I am not sure and suggest consulting a lawyer.
#
# This is not formal legal advice.
#
#
#
# QUESTION: If a tenant is living for more than 10 years and the landlord tries to evict them without notice, what are the tenant’s rights under Indian law?
#
# Based ONLY on the provided case excerpts, there is no information regarding a tenant's rights under Indian law if a landlord tries to evict them without notice after more than 10 years of tenancy. The excerpts discuss:
#
# *   **[CASE 1]**: A show cause notice under Section 25 of the MVAT Act and Rule 30 of the Maharashtra Value Added Tax Rules, 2005, concerning the review of a tax assessment related to a business transfer.
# *   **[CASE 2]**: Whether a transaction violates public policy of India, making awards unenforceable under Section 48(2) of the Arbitration and Conciliation Act, 1996.
# *   **[CASE 3]**: A petition for execution being filed beyond the period of limitation, referencing Article 137 of the Schedule to the Limitation Act, 1963, for the recognition and enforcement of an Award.
#
# As none of these excerpts pertain to landlord-tenant law or eviction, I am not sure how to answer your question based solely on the provided context.
#
# I suggest consulting a lawyer for advice on tenant's rights under Indian law.
#
# This is not formal legal advice.

# %%
questions = [
    "What limitation period did the Court apply for filing a petition to enforce the foreign arbitral awards in IMAX Corporation vs E-City Entertainment (I) Pvt. Ltd., and was the petition held to be within time?",
    "In the IMAX vs E-City Entertainment case, did the Court consider the absence of RBI/FEMA approval as a ground of “public policy of India” to refuse enforcement of the foreign arbitral awards under Section 48 of the Arbitration and Conciliation Act, 1996?",
]

for q in questions:
    print("QUESTION:", q)
    print()
    print(ask_legal_assistant(q))
    print("\n\n")
# Out:
# QUESTION: What limitation period did the Court apply for filing a petition to enforce the foreign arbitral awards in IMAX Corporation vs E-City Entertainment (I) Pvt. Ltd., and was the petition held to be within time?
#
# Based on the provided case excerpts, there is no information regarding the case of IMAX Corporation vs E-City Entertainment (I) Pvt. Ltd., nor any discussion about the limitation period applied for filing a petition to enforce foreign arbitral awards or whether such a petition was held to be within time.
#
# I am not sure. I suggest consulting a lawyer.
#
# This is not formal legal advice.
#
#
#
# QUESTION: In the IMAX vs E-City Entertainment case, did the Court consider the absence of RBI/FEMA approval as a ground of “public policy of India” to refuse enforcement of the foreign arbitral awards under Section 48 of the Arbitration and Conciliation Act, 1996?
#
# Based on the provided case excerpts, there is no information about the "IMAX vs E-City Entertainment" case, nor any discussion regarding the absence of RBI/FEMA approval as a ground of "public policy of India" to refuse enforcement of foreign arbitral awards under Section 48 of the Arbitration and Conciliation Act, 1996.
#
# The provided excerpts discuss:
# *   **[CASE 1]** relates to limitation, res judicata, and the Limitation Act.
# *   **[CASE 2]** pertains to the transfer of IPR rights, corporate logos, trademarks, and a Registered User Agreement.
# *   **[CASE 3]** outlines a structure for arguments and reasoning in a case, but the specific content relevant to your question is not present.
#
# Therefore, I am not sure if the Court considered the absence of RBI/FEMA approval as a ground of "public policy of India" in the "IMAX vs E-City Entertainment" case, as this information is not contained within the provided excerpts. I suggest consulting a lawyer for specific advice on this matter.
#
# This is not formal legal advice.
